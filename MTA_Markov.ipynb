# %%
import numpy as np
import pandas as pd

# %%
d = pd.read_csv('MTA_DATA.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print(d.shape)
print(d.dtypes)
print(d.describe())
d.head()
# Out:
# (10133871, 7)
# RecordID                int64
# Visitor_key             int64
# Hit_date               object
# Order_ind               int64
# CONTAINER_ID          float64
# Channel                object
# Min_Visit Rtrn Cnt      int64
# dtype: object
#            RecordID   Visitor_key     Order_ind  CONTAINER_ID  \
# count  1.013387e+07  1.013387e+07  1.013387e+07  3.986900e+05
# mean   5.066936e+06  1.889485e+08  2.892695e-02  1.219439e+08
# std    2.925397e+06  3.977088e+07  1.676013e-01  1.700850e+07
# min    1.000000e+00  3.038000e+03  0.000000e+00  1.456480e+06
# 25%    2.533468e+06  1.875366e+08  0.000000e+00  1.230413e+08
# 50%    5.066936e+06  2.057652e+08  0.000000e+00  1.266599e+08
# 75%    7.600404e+06  2.111246e+08  0.000000e+00  1.307305e+08
# max    1.013387e+07  2.134299e+08  1.000000e+00  1.349686e+08
#
#        Min_Visit Rtrn Cnt
# count        1.013387e+07
# mean         2.959447e+01
# std          7.948659e+01
# min          1.000000e+00
# 25%          1.000000e+00
# 50%          3.000000e+00
# 75%          2.000000e+01
# max          9.990000e+02
#    RecordID  Visitor_key    Hit_date  Order_ind  CONTAINER_ID      Channel  \
# 0         1    100004047  2018-11-06          0           NaN  Paid Search
# 1         2    100004047  2018-11-07          0           NaN  Paid Search
# 2         3    100004047  2018-11-13          0           NaN  Paid Search
# 3         4    100004047  2018-11-14          0           NaN  Paid Search
# 4         5    100004047  2018-11-07          0           NaN          SEO
#
#    Min_Visit Rtrn Cnt
# 0                  39
# 1                  39
# 2                  39
# 3                  39
# 4                  41

# %%
# Data type clean up
d['Visitor_key'] = d['Visitor_key'].astype('str')
d['CONTAINER_ID'] = d['CONTAINER_ID'].astype('str')
d['Order_ind'] = d['Order_ind'].astype('str')
d['Hit_date'] = d['Hit_date'].astype('datetime64[ns]')
print(d.dtypes)
# Out:
# RecordID                       int64
# Visitor_key                   object
# Hit_date              datetime64[ns]
# Order_ind                     object
# CONTAINER_ID                  object
# Channel                       object
# Min_Visit Rtrn Cnt             int64
# dtype: object

# %%
# Check for nulls
d.isna().sum()
# Out:
# RecordID              0
# Visitor_key           0
# Hit_date              0
# Order_ind             0
# CONTAINER_ID          0
# Channel               0
# Min_Visit Rtrn Cnt    0
# dtype: int64

# %%
d.groupby('Channel').count()
# Out:
#                RecordID  Visitor_key  Hit_date  Order_ind  CONTAINER_ID  \
# Channel
# Digital Event       131          131       131        131           131
# Direct+Other     204203       204203    204203     204203        204203
# Display          884815       884815    884815     884815        884815
# Email            279870       279870    279870     279870        279870
# Friendly URL     272629       272629    272629     272629        272629
# Paid Search     2002360      2002360   2002360    2002360       2002360
# SEO             4371116      4371116   4371116    4371116       4371116
# Social           255328       255328    255328     255328        255328
# Social-Paid       29844        29844     29844      29844         29844
# Unknown         1833575      1833575   1833575    1833575       1833575
#
#                Min_Visit Rtrn Cnt
# Channel
# Digital Event                 131
# Direct+Other               204203
# Display                    884815
# Email                      279870
# Friendly URL               272629
# Paid Search               2002360
# SEO                       4371116
# Social                     255328
# Social-Paid                 29844
# Unknown                   1833575

# %%
# Clean up the channel "Unknown" it is mislebeled
d['Channel'] = d['Channel'].str.replace('Unknown','Direct+Other')
d.groupby('Channel').count()
# Out:
#                RecordID  Visitor_key  Hit_date  Order_ind  CONTAINER_ID  \
# Channel
# Digital Event       131          131       131        131           131
# Direct+Other    2037778      2037778   2037778    2037778       2037778
# Display          884815       884815    884815     884815        884815
# Email            279870       279870    279870     279870        279870
# Friendly URL     272629       272629    272629     272629        272629
# Paid Search     2002360      2002360   2002360    2002360       2002360
# SEO             4371116      4371116   4371116    4371116       4371116
# Social           255328       255328    255328     255328        255328
# Social-Paid       29844        29844     29844      29844         29844
#
#                Min_Visit Rtrn Cnt
# Channel
# Digital Event                 131
# Direct+Other              2037778
# Display                    884815
# Email                      279870
# Friendly URL               272629
# Paid Search               2002360
# SEO                       4371116
# Social                     255328
# Social-Paid                 29844

# %%
# Limiting 10M records to 10,000 to make it easier to work
# I will open this up later...

#d = d.head(10000)

# %%
#Create consistent level of detail within the data

d['grp_fld'] = d.Visitor_key + d.CONTAINER_ID+ d.Order_ind

# %% [markdown]
# ##### Establish Touch Sequences within each journey

# %%
dfa = d.groupby(['grp_fld','Channel','Visitor_key','CONTAINER_ID','Order_ind']).agg({'Min_Visit Rtrn Cnt': 'min'})

dfa = dfa.sort_values(['grp_fld','Min_Visit Rtrn Cnt']).reset_index()

dfa["TouchSeq"] = dfa.groupby('grp_fld')['Min_Visit Rtrn Cnt'].rank(method='dense', ascending=True).astype(int)
dfa.head(10)
# Out:
#                  grp_fld       Channel Visitor_key CONTAINER_ID Order_ind  \
# 0          100004047nan0   Paid Search   100004047          nan         0
# 1          100004047nan0           SEO   100004047          nan         0
# 2          100004089nan0   Paid Search   100004089          nan         0
# 3          100004089nan0           SEO   100004089          nan         0
# 4          100004330nan0           SEO   100004330          nan         0
# 5  100004606114473205.01  Direct+Other   100004606  114473205.0         1
# 6  100004606114473205.01           SEO   100004606  114473205.0         1
# 7  100004606123853417.01  Direct+Other   100004606  123853417.0         1
# 8  100004606123853417.01           SEO   100004606  123853417.0         1
# 9  100004606128357685.01  Direct+Other   100004606  128357685.0         1
#
#    Min_Visit Rtrn Cnt  TouchSeq
# 0                  39         1
# 1                  41         2
# 2                  65         1
# 3                  67         2
# 4                   1         1
# 5                  49         1
# 6                  50         2
# 7                  49         1
# 8                  50         2
# 9                  49         1

# %% [markdown]
# ##### Establish a starting point for each journey (assuming the SP is offsite)

# %%
dfb = d[['grp_fld','Visitor_key','CONTAINER_ID','Order_ind']]
dfb = dfb.drop_duplicates()
dfb['Min_Visit Rtrn Cnt'] = -1 #set to the beginning of the sort order
dfb['TouchSeq'] = 0
dfb['Channel'] = 'Start'

print(dfb.shape)
print(dfb.dtypes)
print(dfb.describe())
dfb.head()
# Out:
# (3972992, 7)
# grp_fld               object
# Visitor_key           object
# CONTAINER_ID          object
# Order_ind             object
# Min_Visit Rtrn Cnt     int64
# TouchSeq               int64
# Channel               object
# dtype: object
#        Min_Visit Rtrn Cnt   TouchSeq
# count           3972992.0  3972992.0
# mean                 -1.0        0.0
# std                   0.0        0.0
# min                  -1.0        0.0
# 25%                  -1.0        0.0
# 50%                  -1.0        0.0
# 75%                  -1.0        0.0
# max                  -1.0        0.0
#           grp_fld Visitor_key CONTAINER_ID Order_ind  Min_Visit Rtrn Cnt  \
# 0   100004047nan0   100004047          nan         0                  -1
# 7   100004089nan0   100004089          nan         0                  -1
# 26  100004330nan0   100004330          nan         0                  -1
# 27  100004713nan0   100004713          nan         0                  -1
# 36  100005387nan0   100005387          nan         0                  -1
#
#     TouchSeq Channel
# 0          0   Start
# 7          0   Start
# 26         0   Start
# 27         0   Start
# 36         0   Start

# %% [markdown]
# ##### Establish ending point for each journey

# %%
dfc = dfa.groupby(['grp_fld','Visitor_key','CONTAINER_ID','Order_ind']).agg({'TouchSeq': 'max'})
dfc = dfc.reset_index()

# use function to determine if order was created
def chan(row):
    if row['Order_ind'] == "1":
        return 'Conv'
    else:
        return 'End'
dfc['Channel'] = dfc.apply(chan, axis=1)

#set final touch sequence number
dfc['TouchSeq'] = dfc['TouchSeq'] + 1

dfc.head()
# Out:
#                  grp_fld Visitor_key CONTAINER_ID Order_ind  TouchSeq Channel
# 0          100004047nan0   100004047          nan         0         3     End
# 1          100004089nan0   100004089          nan         0         3     End
# 2          100004330nan0   100004330          nan         0         2     End
# 3  100004606114473205.01   100004606  114473205.0         1         3    Conv
# 4  100004606123853417.01   100004606  123853417.0         1         3    Conv

# %%
frames = [dfa, dfb, dfc]

dff = pd.concat(frames, axis=0, join='outer', join_axes=None, ignore_index=True,
          keys=None, levels=None, names=None, verify_integrity=False,
          copy=True, sort=True)

dff.shape
dff.sort_values(by=['grp_fld','TouchSeq'] ,inplace=True)
dff.head(100)
# Out:
#         CONTAINER_ID       Channel  Min_Visit Rtrn Cnt Order_ind  TouchSeq  \
# 4862989          nan         Start                -1.0         0         0
# 0                nan   Paid Search                39.0         0         1
# 1                nan           SEO                41.0         0         2
# 8835981          nan           End                 NaN         0         3
# 4862990          nan         Start                -1.0         0         0
# 2                nan   Paid Search                65.0         0         1
# 3                nan           SEO                67.0         0         2
# 8835982          nan           End                 NaN         0         3
# 4862991          nan         Start                -1.0         0         0
# 4                nan           SEO                 1.0         0         1
# 8835983          nan           End                 NaN         0         2
# 8695446  114473205.0         Start                -1.0         1         0
# 5        114473205.0  Direct+Other                49.0         1         1
# 6        114473205.0           SEO                50.0         1         2
# 8835984  114473205.0          Conv                 NaN         1         3
# 8717025  123853417.0         Start                -1.0         1         0
# 7        123853417.0  Direct+Other                49.0         1         1
# 8        123853417.0           SEO                50.0         1         2
# 8835985  123853417.0          Conv                 NaN         1         3
# 8763984  128357685.0         Start                -1.0         1         0
# 9        128357685.0  Direct+Other                49.0         1         1
# 10       128357685.0           SEO                50.0         1         2
# 8835986  128357685.0          Conv                 NaN         1         3
# 8810300  133606647.0         Start                -1.0         1         0
# 11       133606647.0  Direct+Other                49.0         1         1
# 12       133606647.0           SEO                50.0         1         2
# 8835987  133606647.0          Conv                 NaN         1         3
# 8810337  133608169.0         Start                -1.0         1         0
# 13       133608169.0  Direct+Other                49.0         1         1
# 14       133608169.0           SEO                50.0         1         2
# ...              ...           ...                 ...       ...       ...
# 8835998  132054073.0          Conv                 NaN         1         3
# 8800463  132057416.0         Start                -1.0         1         0
# 35       132057416.0   Paid Search                64.0         1         1
# 36       132057416.0           SEO                67.0         1         2
# 37       132057416.0  Direct+Other                71.0         1         3
# 8835999  132057416.0          Conv                 NaN         1         4
# 4863001          nan         Start                -1.0         0         0
# 38               nan           SEO                36.0         0         1
# 39               nan  Direct+Other                38.0         0         2
# 8836000          nan           End                 NaN         0         3
# 4863002          nan         Start                -1.0         0         0
# 40               nan  Direct+Other                73.0         0         1
# 8836001          nan           End                 NaN         0         2
# 4863003          nan         Start                -1.0         0         0
# 41               nan         Email                 1.0         0         1
# 8836002          nan           End                 NaN         0         2
# 4863004          nan         Start                -1.0         0         0
# 42               nan           SEO                 5.0         0         1
# 8836003          nan           End                 NaN         0         2
# 4863005          nan         Start                -1.0         0         0
# 43               nan           SEO                60.0         0         1
# 44               nan  Direct+Other                70.0         0         2
# 8836004          nan           End                 NaN         0         3
# 4863006          nan         Start                -1.0         0         0
# 45               nan           SEO                96.0         0         1
# 46               nan  Direct+Other               100.0         0         2
# 8836005          nan           End                 NaN         0         3
# 4863007          nan         Start                -1.0         0         0
# 47               nan  Direct+Other                 4.0         0         1
# 48               nan           SEO                 5.0         0         2
#
#         Visitor_key                grp_fld
# 4862989   100004047          100004047nan0
# 0         100004047          100004047nan0
# 1         100004047          100004047nan0
# 8835981   100004047          100004047nan0
# 4862990   100004089          100004089nan0
# 2         100004089          100004089nan0
# 3         100004089          100004089nan0
# 8835982   100004089          100004089nan0
# 4862991   100004330          100004330nan0
# 4         100004330          100004330nan0
# 8835983   100004330          100004330nan0
# 8695446   100004606  100004606114473205.01
# 5         100004606  100004606114473205.01
# 6         100004606  100004606114473205.01
# 8835984   100004606  100004606114473205.01
# 8717025   100004606  100004606123853417.01
# 7         100004606  100004606123853417.01
# 8         100004606  100004606123853417.01
# 8835985   100004606  100004606123853417.01
# 8763984   100004606  100004606128357685.01
# 9         100004606  100004606128357685.01
# 10        100004606  100004606128357685.01
# 8835986   100004606  100004606128357685.01
# 8810300   100004606  100004606133606647.01
# 11        100004606  100004606133606647.01
# 12        100004606  100004606133606647.01
# 8835987   100004606  100004606133606647.01
# 8810337   100004606  100004606133608169.01
# 13        100004606  100004606133608169.01
# 14        100004606  100004606133608169.01
# ...             ...                    ...
# 8835998   100015620  100015620132054073.01
# 8800463   100015620  100015620132057416.01
# 35        100015620  100015620132057416.01
# 36        100015620  100015620132057416.01
# 37        100015620  100015620132057416.01
# 8835999   100015620  100015620132057416.01
# 4863001   100015648          100015648nan0
# 38        100015648          100015648nan0
# 39        100015648          100015648nan0
# 8836000   100015648          100015648nan0
# 4863002   100015656          100015656nan0
# 40        100015656          100015656nan0
# 8836001   100015656          100015656nan0
# 4863003   100015879          100015879nan0
# 41        100015879          100015879nan0
# 8836002   100015879          100015879nan0
# 4863004   100016329          100016329nan0
# 42        100016329          100016329nan0
# 8836003   100016329          100016329nan0
# 4863005   100016384          100016384nan0
# 43        100016384          100016384nan0
# 44        100016384          100016384nan0
# 8836004   100016384          100016384nan0
# 4863006   100016408          100016408nan0
# 45        100016408          100016408nan0
# 46        100016408          100016408nan0
# 8836005   100016408          100016408nan0
# 4863007   100016452          100016452nan0
# 47        100016452          100016452nan0
# 48        100016452          100016452nan0
#
# [100 rows x 7 columns]

# %%
dff.shape
# Out:
# (12808973, 7)

# %%
# Select relevant columns for Markov Chain Analysis
journeys = dff[['grp_fld','Visitor_key','Order_ind','CONTAINER_ID','TouchSeq','Channel']]
journeys.reset_index(drop=True, inplace=True)

# not used, just a thought..
#journeys['Path'] = journeys.groupby(['grp_fld','Visitor_key','Order_ind','CONTAINER_ID'])['Channel'].transform(lambda x: '>'.join(x))

# %%
conditions = ['End','Conv']
journeys['Transition'] = np.where(journeys['Channel'].isin(conditions),np.nan ,journeys['Channel'].shift(-1))
#journeys['Channel'] = journeys['Channel'].shift(-1)
journeys.head(50)
# Out:
#                   grp_fld Visitor_key Order_ind CONTAINER_ID  TouchSeq  \
# 0           100004047nan0   100004047         0          nan         0
# 1           100004047nan0   100004047         0          nan         1
# 2           100004047nan0   100004047         0          nan         2
# 3           100004047nan0   100004047         0          nan         3
# 4           100004089nan0   100004089         0          nan         0
# 5           100004089nan0   100004089         0          nan         1
# 6           100004089nan0   100004089         0          nan         2
# 7           100004089nan0   100004089         0          nan         3
# 8           100004330nan0   100004330         0          nan         0
# 9           100004330nan0   100004330         0          nan         1
# 10          100004330nan0   100004330         0          nan         2
# 11  100004606114473205.01   100004606         1  114473205.0         0
# 12  100004606114473205.01   100004606         1  114473205.0         1
# 13  100004606114473205.01   100004606         1  114473205.0         2
# 14  100004606114473205.01   100004606         1  114473205.0         3
# 15  100004606123853417.01   100004606         1  123853417.0         0
# 16  100004606123853417.01   100004606         1  123853417.0         1
# 17  100004606123853417.01   100004606         1  123853417.0         2
# 18  100004606123853417.01   100004606         1  123853417.0         3
# 19  100004606128357685.01   100004606         1  128357685.0         0
# 20  100004606128357685.01   100004606         1  128357685.0         1
# 21  100004606128357685.01   100004606         1  128357685.0         2
# 22  100004606128357685.01   100004606         1  128357685.0         3
# 23  100004606133606647.01   100004606         1  133606647.0         0
# 24  100004606133606647.01   100004606         1  133606647.0         1
# 25  100004606133606647.01   100004606         1  133606647.0         2
# 26  100004606133606647.01   100004606         1  133606647.0         3
# 27  100004606133608169.01   100004606         1  133608169.0         0
# 28  100004606133608169.01   100004606         1  133608169.0         1
# 29  100004606133608169.01   100004606         1  133608169.0         2
# 30  100004606133608169.01   100004606         1  133608169.0         3
# 31          100004713nan0   100004713         0          nan         0
# 32          100004713nan0   100004713         0          nan         1
# 33          100004713nan0   100004713         0          nan         2
# 34          100004713nan0   100004713         0          nan         3
# 35          100004713nan0   100004713         0          nan         4
# 36          100005387nan0   100005387         0          nan         0
# 37          100005387nan0   100005387         0          nan         1
# 38          100005387nan0   100005387         0          nan         2
# 39          100005707nan0   100005707         0          nan         0
# 40          100005707nan0   100005707         0          nan         1
# 41          100005707nan0   100005707         0          nan         2
# 42          100005707nan0   100005707         0          nan         3
# 43          100005707nan0   100005707         0          nan         4
# 44            1000141nan0     1000141         0          nan         0
# 45            1000141nan0     1000141         0          nan         1
# 46            1000141nan0     1000141         0          nan         1
# 47            1000141nan0     1000141         0          nan         2
# 48            1000141nan0     1000141         0          nan         3
# 49          100014699nan0   100014699         0          nan         0
#
#          Channel    Transition
# 0          Start   Paid Search
# 1    Paid Search           SEO
# 2            SEO           End
# 3            End           NaN
# 4          Start   Paid Search
# 5    Paid Search           SEO
# 6            SEO           End
# 7            End           NaN
# 8          Start           SEO
# 9            SEO           End
# 10           End           NaN
# 11         Start  Direct+Other
# 12  Direct+Other           SEO
# 13           SEO          Conv
# 14          Conv           NaN
# 15         Start  Direct+Other
# 16  Direct+Other           SEO
# 17           SEO          Conv
# 18          Conv           NaN
# 19         Start  Direct+Other
# 20  Direct+Other           SEO
# 21           SEO          Conv
# 22          Conv           NaN
# 23         Start  Direct+Other
# 24  Direct+Other           SEO
# 25           SEO          Conv
# 26          Conv           NaN
# 27         Start  Direct+Other
# 28  Direct+Other           SEO
# 29           SEO          Conv
# 30          Conv           NaN
# 31         Start   Paid Search
# 32   Paid Search  Direct+Other
# 33  Direct+Other           SEO
# 34           SEO           End
# 35           End           NaN
# 36         Start         Email
# 37         Email           End
# 38           End           NaN
# 39         Start           SEO
# 40           SEO  Direct+Other
# 41  Direct+Other   Paid Search
# 42   Paid Search           End
# 43           End           NaN
# 44         Start   Paid Search
# 45   Paid Search           SEO
# 46           SEO  Direct+Other
# 47  Direct+Other           End
# 48           End           NaN
# 49         Start   Paid Search

# %%
# Filter the End and Conv from channel
# this represents the starting point from which a customer transtions to another channel
# these two conditions have no transition

journeys = journeys.loc[(journeys.Channel != 'End') & (journeys.Channel != 'Conv')]
journeys.head(20)
# Out:
#                   grp_fld Visitor_key Order_ind CONTAINER_ID  TouchSeq  \
# 0           100004047nan0   100004047         0          nan         0
# 1           100004047nan0   100004047         0          nan         1
# 2           100004047nan0   100004047         0          nan         2
# 4           100004089nan0   100004089         0          nan         0
# 5           100004089nan0   100004089         0          nan         1
# 6           100004089nan0   100004089         0          nan         2
# 8           100004330nan0   100004330         0          nan         0
# 9           100004330nan0   100004330         0          nan         1
# 11  100004606114473205.01   100004606         1  114473205.0         0
# 12  100004606114473205.01   100004606         1  114473205.0         1
# 13  100004606114473205.01   100004606         1  114473205.0         2
# 15  100004606123853417.01   100004606         1  123853417.0         0
# 16  100004606123853417.01   100004606         1  123853417.0         1
# 17  100004606123853417.01   100004606         1  123853417.0         2
# 19  100004606128357685.01   100004606         1  128357685.0         0
# 20  100004606128357685.01   100004606         1  128357685.0         1
# 21  100004606128357685.01   100004606         1  128357685.0         2
# 23  100004606133606647.01   100004606         1  133606647.0         0
# 24  100004606133606647.01   100004606         1  133606647.0         1
# 25  100004606133606647.01   100004606         1  133606647.0         2
#
#          Channel    Transition
# 0          Start   Paid Search
# 1    Paid Search           SEO
# 2            SEO           End
# 4          Start   Paid Search
# 5    Paid Search           SEO
# 6            SEO           End
# 8          Start           SEO
# 9            SEO           End
# 11         Start  Direct+Other
# 12  Direct+Other           SEO
# 13           SEO          Conv
# 15         Start  Direct+Other
# 16  Direct+Other           SEO
# 17           SEO          Conv
# 19         Start  Direct+Other
# 20  Direct+Other           SEO
# 21           SEO          Conv
# 23         Start  Direct+Other
# 24  Direct+Other           SEO
# 25           SEO          Conv

# %%
# Create lookup table with total number of transitions per Channel
initial_channel_counts = journeys.groupby('Channel').agg ({'Transition': 'count'}).reset_index()
initial_channel_counts.rename(columns={'Transition':'Total_transitions'}, inplace=True)
initial_channel_counts.columns
# Out:
# Index([u'Channel', u'Total_transitions'], dtype='object')

# %%
# Join the lookup table to the transitions table, to pull in the counts for each starting state, t.
Transitions = pd.merge(journeys, initial_channel_counts, on='Channel', how='left')
Transitions.head(100)
# Out:
#                   grp_fld Visitor_key Order_ind CONTAINER_ID  TouchSeq  \
# 0           100004047nan0   100004047         0          nan         0
# 1           100004047nan0   100004047         0          nan         1
# 2           100004047nan0   100004047         0          nan         2
# 3           100004089nan0   100004089         0          nan         0
# 4           100004089nan0   100004089         0          nan         1
# 5           100004089nan0   100004089         0          nan         2
# 6           100004330nan0   100004330         0          nan         0
# 7           100004330nan0   100004330         0          nan         1
# 8   100004606114473205.01   100004606         1  114473205.0         0
# 9   100004606114473205.01   100004606         1  114473205.0         1
# 10  100004606114473205.01   100004606         1  114473205.0         2
# 11  100004606123853417.01   100004606         1  123853417.0         0
# 12  100004606123853417.01   100004606         1  123853417.0         1
# 13  100004606123853417.01   100004606         1  123853417.0         2
# 14  100004606128357685.01   100004606         1  128357685.0         0
# 15  100004606128357685.01   100004606         1  128357685.0         1
# 16  100004606128357685.01   100004606         1  128357685.0         2
# 17  100004606133606647.01   100004606         1  133606647.0         0
# 18  100004606133606647.01   100004606         1  133606647.0         1
# 19  100004606133606647.01   100004606         1  133606647.0         2
# 20  100004606133608169.01   100004606         1  133608169.0         0
# 21  100004606133608169.01   100004606         1  133608169.0         1
# 22  100004606133608169.01   100004606         1  133608169.0         2
# 23          100004713nan0   100004713         0          nan         0
# 24          100004713nan0   100004713         0          nan         1
# 25          100004713nan0   100004713         0          nan         2
# 26          100004713nan0   100004713         0          nan         3
# 27          100005387nan0   100005387         0          nan         0
# 28          100005387nan0   100005387         0          nan         1
# 29          100005707nan0   100005707         0          nan         0
# ..                    ...         ...       ...          ...       ...
# 70          100016408nan0   100016408         0          nan         1
# 71          100016408nan0   100016408         0          nan         2
# 72          100016452nan0   100016452         0          nan         0
# 73          100016452nan0   100016452         0          nan         1
# 74          100016452nan0   100016452         0          nan         2
# 75          100016787nan0   100016787         0          nan         0
# 76          100016787nan0   100016787         0          nan         1
# 77          100016787nan0   100016787         0          nan         2
# 78          100017382nan0   100017382         0          nan         0
# 79          100017382nan0   100017382         0          nan         1
# 80          100017382nan0   100017382         0          nan         2
# 81           10001753nan0    10001753         0          nan         0
# 82           10001753nan0    10001753         0          nan         1
# 83          100017579nan0   100017579         0          nan         0
# 84          100017579nan0   100017579         0          nan         1
# 85          100017603nan0   100017603         0          nan         0
# 86          100017603nan0   100017603         0          nan         1
# 87            1000215nan0     1000215         0          nan         0
# 88            1000215nan0     1000215         0          nan         1
# 89            1000215nan0     1000215         0          nan         2
# 90            1000215nan0     1000215         0          nan         3
# 91          100025870nan0   100025870         0          nan         0
# 92          100025870nan0   100025870         0          nan         1
# 93          100025870nan0   100025870         0          nan         2
# 94          100026102nan0   100026102         0          nan         0
# 95          100026102nan0   100026102         0          nan         1
# 96          100026121nan0   100026121         0          nan         0
# 97          100026121nan0   100026121         0          nan         1
# 98          100026134nan0   100026134         0          nan         0
# 99          100026134nan0   100026134         0          nan         1
#
#          Channel    Transition  Total_transitions
# 0          Start   Paid Search            3972992
# 1    Paid Search           SEO             894252
# 2            SEO           End            1976015
# 3          Start   Paid Search            3972992
# 4    Paid Search           SEO             894252
# 5            SEO           End            1976015
# 6          Start           SEO            3972992
# 7            SEO           End            1976015
# 8          Start  Direct+Other            3972992
# 9   Direct+Other           SEO            1281018
# 10           SEO          Conv            1976015
# 11         Start  Direct+Other            3972992
# 12  Direct+Other           SEO            1281018
# 13           SEO          Conv            1976015
# 14         Start  Direct+Other            3972992
# 15  Direct+Other           SEO            1281018
# 16           SEO          Conv            1976015
# 17         Start  Direct+Other            3972992
# 18  Direct+Other           SEO            1281018
# 19           SEO          Conv            1976015
# 20         Start  Direct+Other            3972992
# 21  Direct+Other           SEO            1281018
# 22           SEO          Conv            1976015
# 23         Start   Paid Search            3972992
# 24   Paid Search  Direct+Other             894252
# 25  Direct+Other           SEO            1281018
# 26           SEO           End            1976015
# 27         Start         Email            3972992
# 28         Email           End              69817
# 29         Start           SEO            3972992
# ..           ...           ...                ...
# 70           SEO  Direct+Other            1976015
# 71  Direct+Other           End            1281018
# 72         Start  Direct+Other            3972992
# 73  Direct+Other           SEO            1281018
# 74           SEO           End            1976015
# 75         Start  Direct+Other            3972992
# 76  Direct+Other           SEO            1281018
# 77           SEO           End            1976015
# 78         Start  Direct+Other            3972992
# 79  Direct+Other           SEO            1281018
# 80           SEO           End            1976015
# 81         Start           SEO            3972992
# 82           SEO           End            1976015
# 83         Start           SEO            3972992
# 84           SEO           End            1976015
# 85         Start           SEO            3972992
# 86           SEO           End            1976015
# 87         Start           SEO            3972992
# 88           SEO  Direct+Other            1976015
# 89  Direct+Other   Paid Search            1281018
# 90   Paid Search           End             894252
# 91         Start           SEO            3972992
# 92           SEO  Direct+Other            1976015
# 93  Direct+Other           End            1281018
# 94         Start           SEO            3972992
# 95           SEO           End            1976015
# 96         Start           SEO            3972992
# 97           SEO           End            1976015
# 98         Start           SEO            3972992
# 99           SEO           End            1976015
#
# [100 rows x 8 columns]

# %%
Transitions['probability'] = 1/Transitions['Total_transitions']
Transitions.head(100)
# Out:
#                   grp_fld Visitor_key Order_ind CONTAINER_ID  TouchSeq  \
# 0           100004047nan0   100004047         0          nan         0
# 1           100004047nan0   100004047         0          nan         1
# 2           100004047nan0   100004047         0          nan         2
# 3           100004089nan0   100004089         0          nan         0
# 4           100004089nan0   100004089         0          nan         1
# 5           100004089nan0   100004089         0          nan         2
# 6           100004330nan0   100004330         0          nan         0
# 7           100004330nan0   100004330         0          nan         1
# 8   100004606114473205.01   100004606         1  114473205.0         0
# 9   100004606114473205.01   100004606         1  114473205.0         1
# 10  100004606114473205.01   100004606         1  114473205.0         2
# 11  100004606123853417.01   100004606         1  123853417.0         0
# 12  100004606123853417.01   100004606         1  123853417.0         1
# 13  100004606123853417.01   100004606         1  123853417.0         2
# 14  100004606128357685.01   100004606         1  128357685.0         0
# 15  100004606128357685.01   100004606         1  128357685.0         1
# 16  100004606128357685.01   100004606         1  128357685.0         2
# 17  100004606133606647.01   100004606         1  133606647.0         0
# 18  100004606133606647.01   100004606         1  133606647.0         1
# 19  100004606133606647.01   100004606         1  133606647.0         2
# 20  100004606133608169.01   100004606         1  133608169.0         0
# 21  100004606133608169.01   100004606         1  133608169.0         1
# 22  100004606133608169.01   100004606         1  133608169.0         2
# 23          100004713nan0   100004713         0          nan         0
# 24          100004713nan0   100004713         0          nan         1
# 25          100004713nan0   100004713         0          nan         2
# 26          100004713nan0   100004713         0          nan         3
# 27          100005387nan0   100005387         0          nan         0
# 28          100005387nan0   100005387         0          nan         1
# 29          100005707nan0   100005707         0          nan         0
# ..                    ...         ...       ...          ...       ...
# 70          100016408nan0   100016408         0          nan         1
# 71          100016408nan0   100016408         0          nan         2
# 72          100016452nan0   100016452         0          nan         0
# 73          100016452nan0   100016452         0          nan         1
# 74          100016452nan0   100016452         0          nan         2
# 75          100016787nan0   100016787         0          nan         0
# 76          100016787nan0   100016787         0          nan         1
# 77          100016787nan0   100016787         0          nan         2
# 78          100017382nan0   100017382         0          nan         0
# 79          100017382nan0   100017382         0          nan         1
# 80          100017382nan0   100017382         0          nan         2
# 81           10001753nan0    10001753         0          nan         0
# 82           10001753nan0    10001753         0          nan         1
# 83          100017579nan0   100017579         0          nan         0
# 84          100017579nan0   100017579         0          nan         1
# 85          100017603nan0   100017603         0          nan         0
# 86          100017603nan0   100017603         0          nan         1
# 87            1000215nan0     1000215         0          nan         0
# 88            1000215nan0     1000215         0          nan         1
# 89            1000215nan0     1000215         0          nan         2
# 90            1000215nan0     1000215         0          nan         3
# 91          100025870nan0   100025870         0          nan         0
# 92          100025870nan0   100025870         0          nan         1
# 93          100025870nan0   100025870         0          nan         2
# 94          100026102nan0   100026102         0          nan         0
# 95          100026102nan0   100026102         0          nan         1
# 96          100026121nan0   100026121         0          nan         0
# 97          100026121nan0   100026121         0          nan         1
# 98          100026134nan0   100026134         0          nan         0
# 99          100026134nan0   100026134         0          nan         1
#
#          Channel    Transition  Total_transitions   probability
# 0          Start   Paid Search            3972992  2.516995e-07
# 1    Paid Search           SEO             894252  1.118253e-06
# 2            SEO           End            1976015  5.060690e-07
# 3          Start   Paid Search            3972992  2.516995e-07
# 4    Paid Search           SEO             894252  1.118253e-06
# 5            SEO           End            1976015  5.060690e-07
# 6          Start           SEO            3972992  2.516995e-07
# 7            SEO           End            1976015  5.060690e-07
# 8          Start  Direct+Other            3972992  2.516995e-07
# 9   Direct+Other           SEO            1281018  7.806292e-07
# 10           SEO          Conv            1976015  5.060690e-07
# 11         Start  Direct+Other            3972992  2.516995e-07
# 12  Direct+Other           SEO            1281018  7.806292e-07
# 13           SEO          Conv            1976015  5.060690e-07
# 14         Start  Direct+Other            3972992  2.516995e-07
# 15  Direct+Other           SEO            1281018  7.806292e-07
# 16           SEO          Conv            1976015  5.060690e-07
# 17         Start  Direct+Other            3972992  2.516995e-07
# 18  Direct+Other           SEO            1281018  7.806292e-07
# 19           SEO          Conv            1976015  5.060690e-07
# 20         Start  Direct+Other            3972992  2.516995e-07
# 21  Direct+Other           SEO            1281018  7.806292e-07
# 22           SEO          Conv            1976015  5.060690e-07
# 23         Start   Paid Search            3972992  2.516995e-07
# 24   Paid Search  Direct+Other             894252  1.118253e-06
# 25  Direct+Other           SEO            1281018  7.806292e-07
# 26           SEO           End            1976015  5.060690e-07
# 27         Start         Email            3972992  2.516995e-07
# 28         Email           End              69817  1.432316e-05
# 29         Start           SEO            3972992  2.516995e-07
# ..           ...           ...                ...           ...
# 70           SEO  Direct+Other            1976015  5.060690e-07
# 71  Direct+Other           End            1281018  7.806292e-07
# 72         Start  Direct+Other            3972992  2.516995e-07
# 73  Direct+Other           SEO            1281018  7.806292e-07
# 74           SEO           End            1976015  5.060690e-07
# 75         Start  Direct+Other            3972992  2.516995e-07
# 76  Direct+Other           SEO            1281018  7.806292e-07
# 77           SEO           End            1976015  5.060690e-07
# 78         Start  Direct+Other            3972992  2.516995e-07
# 79  Direct+Other           SEO            1281018  7.806292e-07
# 80           SEO           End            1976015  5.060690e-07
# 81         Start           SEO            3972992  2.516995e-07
# 82           SEO           End            1976015  5.060690e-07
# 83         Start           SEO            3972992  2.516995e-07
# 84           SEO           End            1976015  5.060690e-07
# 85         Start           SEO            3972992  2.516995e-07
# 86           SEO           End            1976015  5.060690e-07
# 87         Start           SEO            3972992  2.516995e-07
# 88           SEO  Direct+Other            1976015  5.060690e-07
# 89  Direct+Other   Paid Search            1281018  7.806292e-07
# 90   Paid Search           End             894252  1.118253e-06
# 91         Start           SEO            3972992  2.516995e-07
# 92           SEO  Direct+Other            1976015  5.060690e-07
# 93  Direct+Other           End            1281018  7.806292e-07
# 94         Start           SEO            3972992  2.516995e-07
# 95           SEO           End            1976015  5.060690e-07
# 96         Start           SEO            3972992  2.516995e-07
# 97           SEO           End            1976015  5.060690e-07
# 98         Start           SEO            3972992  2.516995e-07
# 99           SEO           End            1976015  5.060690e-07
#
# [100 rows x 9 columns]

# %%
# Check totals, that porbability is 1
df_test = Transitions.groupby('Channel').agg({'probability': 'sum'})
df_test
# Out:
#                probability
# Channel
# Digital Event          1.0
# Direct+Other           1.0
# Display                1.0
# Email                  1.0
# Friendly URL           1.0
# Paid Search            1.0
# SEO                    1.0
# Social                 1.0
# Social-Paid            1.0
# Start                  1.0

# %%
df_transition_prob = Transitions.groupby(['Channel','Transition']).agg({'probability':'sum'}).reset_index()
df_transition_prob
# Out:
#           Channel     Transition  probability
# 0   Digital Event           Conv     0.133333
# 1   Digital Event   Direct+Other     0.177778
# 2   Digital Event          Email     0.044444
# 3   Digital Event            End     0.288889
# 4   Digital Event   Friendly URL     0.088889
# 5   Digital Event    Paid Search     0.200000
# 6   Digital Event            SEO     0.044444
# 7   Digital Event         Social     0.022222
# 8    Direct+Other           Conv     0.034686
# 9    Direct+Other  Digital Event     0.000009
# 10   Direct+Other        Display     0.011022
# 11   Direct+Other          Email     0.007309
# 12   Direct+Other            End     0.740681
# 13   Direct+Other   Friendly URL     0.024576
# 14   Direct+Other    Paid Search     0.047030
# 15   Direct+Other            SEO     0.126446
# 16   Direct+Other         Social     0.007784
# 17   Direct+Other    Social-Paid     0.000456
# 18        Display           Conv     0.002898
# 19        Display  Digital Event     0.000008
# 20        Display   Direct+Other     0.007115
# 21        Display          Email     0.002006
# 22        Display            End     0.949556
# 23        Display   Friendly URL     0.003694
# 24        Display    Paid Search     0.021384
# 25        Display            SEO     0.012276
# 26        Display         Social     0.000840
# 27        Display    Social-Paid     0.000223
# 28          Email           Conv     0.055359
# 29          Email  Digital Event     0.000115
# ..            ...            ...          ...
# 65            SEO    Paid Search     0.061455
# 66            SEO         Social     0.003784
# 67            SEO    Social-Paid     0.000206
# 68         Social           Conv     0.003532
# 69         Social   Direct+Other     0.015908
# 70         Social        Display     0.005079
# 71         Social          Email     0.004008
# 72         Social            End     0.924602
# 73         Social   Friendly URL     0.004454
# 74         Social    Paid Search     0.008540
# 75         Social            SEO     0.019056
# 76         Social    Social-Paid     0.014822
# 77    Social-Paid           Conv     0.001343
# 78    Social-Paid   Direct+Other     0.018414
# 79    Social-Paid        Display     0.008504
# 80    Social-Paid          Email     0.001790
# 81    Social-Paid            End     0.901215
# 82    Social-Paid   Friendly URL     0.001662
# 83    Social-Paid    Paid Search     0.004412
# 84    Social-Paid            SEO     0.009974
# 85    Social-Paid         Social     0.052685
# 86          Start  Digital Event     0.000002
# 87          Start   Direct+Other     0.260499
# 88          Start        Display     0.091594
# 89          Start          Email     0.009775
# 90          Start   Friendly URL     0.007701
# 91          Start    Paid Search     0.174532
# 92          Start            SEO     0.425708
# 93          Start         Social     0.027068
# 94          Start    Social-Paid     0.003121
#
# [95 rows x 3 columns]

# %%
#Fit DataFrame to code
df_transition_prob.rename(columns={'Channel':'t','Transition':'t_plus_1'}, inplace=True)

df_transition_prob
# Out:
#                 t       t_plus_1  probability
# 0   Digital Event           Conv     0.133333
# 1   Digital Event   Direct+Other     0.177778
# 2   Digital Event          Email     0.044444
# 3   Digital Event            End     0.288889
# 4   Digital Event   Friendly URL     0.088889
# 5   Digital Event    Paid Search     0.200000
# 6   Digital Event            SEO     0.044444
# 7   Digital Event         Social     0.022222
# 8    Direct+Other           Conv     0.034686
# 9    Direct+Other  Digital Event     0.000009
# 10   Direct+Other        Display     0.011022
# 11   Direct+Other          Email     0.007309
# 12   Direct+Other            End     0.740681
# 13   Direct+Other   Friendly URL     0.024576
# 14   Direct+Other    Paid Search     0.047030
# 15   Direct+Other            SEO     0.126446
# 16   Direct+Other         Social     0.007784
# 17   Direct+Other    Social-Paid     0.000456
# 18        Display           Conv     0.002898
# 19        Display  Digital Event     0.000008
# 20        Display   Direct+Other     0.007115
# 21        Display          Email     0.002006
# 22        Display            End     0.949556
# 23        Display   Friendly URL     0.003694
# 24        Display    Paid Search     0.021384
# 25        Display            SEO     0.012276
# 26        Display         Social     0.000840
# 27        Display    Social-Paid     0.000223
# 28          Email           Conv     0.055359
# 29          Email  Digital Event     0.000115
# ..            ...            ...          ...
# 65            SEO    Paid Search     0.061455
# 66            SEO         Social     0.003784
# 67            SEO    Social-Paid     0.000206
# 68         Social           Conv     0.003532
# 69         Social   Direct+Other     0.015908
# 70         Social        Display     0.005079
# 71         Social          Email     0.004008
# 72         Social            End     0.924602
# 73         Social   Friendly URL     0.004454
# 74         Social    Paid Search     0.008540
# 75         Social            SEO     0.019056
# 76         Social    Social-Paid     0.014822
# 77    Social-Paid           Conv     0.001343
# 78    Social-Paid   Direct+Other     0.018414
# 79    Social-Paid        Display     0.008504
# 80    Social-Paid          Email     0.001790
# 81    Social-Paid            End     0.901215
# 82    Social-Paid   Friendly URL     0.001662
# 83    Social-Paid    Paid Search     0.004412
# 84    Social-Paid            SEO     0.009974
# 85    Social-Paid         Social     0.052685
# 86          Start  Digital Event     0.000002
# 87          Start   Direct+Other     0.260499
# 88          Start        Display     0.091594
# 89          Start          Email     0.009775
# 90          Start   Friendly URL     0.007701
# 91          Start    Paid Search     0.174532
# 92          Start            SEO     0.425708
# 93          Start         Social     0.027068
# 94          Start    Social-Paid     0.003121
#
# [95 rows x 3 columns]

# %% [markdown]
# ### Calculate Total Conversion Probability

# %%
def print_node(node, debug=False):
    # Print each node as it's processed. For debugging purposes.
    
    if not debug:
        return
    
    if node['t_plus_1'] in ['End', 'Conv']:
        node_type = 'Leaf'
    else:
        node_type = 'Parent'
    
    print('%s > %s' % (node['t'], node['t_plus_1']))
    print('Type: %s' % node_type)
    print('Prob: %0.2f' % node['probability'])
    print('----------------------------')

# %% [markdown]
# ### ASSUMES THE TRANSITION DATAFRAME REPRESENTS A "DAG"
# ###### https://www.python-course.eu/graphs_python.php  for solution ideas...

# %%
calculated_node_probabilities = dict()

def calc_conversion_probability(starting_state, df_transitions, cum_probability, calculated_nodes, debug=True):
    # Calculates the cumulative probability of reaching a conversion, given a starting state.
    # Assumes the transition dataframe represents a Directed Acyclic Graph (DAG)
        
    # Get the transition probabilities for the starting state we're evaluating
    df_nodes = df_transitions[df_transitions['t'] == starting_state]

    
    # Loop through the starting states and either return the probability for 
    # a leaf node, or recurse to keep following the tree.
    
    node_conversion_probability = 0
    
    child_node_proabilities = []
    
    for index, row in df_nodes.iterrows():
        
        # These are leaf nodes: either an exit or conversion
        if row['t_plus_1'] == 'End':
            print_node(row, debug)
            child_node_proabilities.append(0)
        
        elif row['t_plus_1'] == 'Conv':
            print_node(row, debug)
            child_node_proabilities.append(row['probability'])
        
        # This is a parent node: Keep following the rabbit hole
        else:
            
            # Have we cached the total probability for this node???
            if row['t_plus_1'] in calculated_nodes:
                if debug:
                    print('Cache Hit for %s! Cum probability from child: %0.2f' % (row['t_plus_1'], calculated_nodes[row['t_plus_1']]))
                child_probability = calculated_nodes[row['t_plus_1']]
            
            # No cached value found. We'll walk through the tree to calculated the value.
            else:
                # Recursive call
                child_probability = calc_conversion_probability(row['t_plus_1'], 
                                                                df_transitions, 
                                                                cum_probability + row['probability'],
                                                                calculated_nodes, 
                                                                debug)
                node_conversion_prob = child_probability * row['probability']
                
            print_node(row, debug)
            child_node_proabilities.append(node_conversion_prob)
                    
            if debug:
                print('%s > %s' % (row['t'], row['t_plus_1']))
                print('Cum Prob from Child : %0.2f' % child_probability)
                print('Prob to Child Node  : %0.2f' % row['probability'])
                print('Node Conv Proability: %0.2f' % node_conversion_prob)
                print('----------------------------')
    
    total_node_probability = sum(child_node_proabilities)
    if debug:
        print('Node Conversion Probability for %s: %0.2f' % (starting_state, total_node_probability))
        print('----------------------------')
    
    # We'll cache the calculated total probability for the node, so we don't have to calculate it again.
    calculated_node_probabilities[starting_state] = total_node_probability
        
    return total_node_probability

# %%
starting_node = 'SEO'
print('====== START DEBUG PRINT ======')
total_probability = calc_conversion_probability(starting_node, df_transition_prob, 0, calculated_node_probabilities)
print('====== END DEBUG PRINT ======')
print(' ')
print('Total Conversion Probability from %s: %0.2f' % (starting_node, total_probability))
# Out:
# ====== START DEBUG PRINT ======
# SEO > Conv
# Type: Leaf
# Prob: 0.01
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# ...
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# Digital Event > Conv
# Type: Leaf
# Prob: 0.13
# ----------------------------
# Direct+Other > Conv
# Type: Leaf
# Prob: 0.03
# ----------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-7cb13dc1d65d> in <module>()
#       1 starting_node = 'SEO'
#       2 print('====== START DEBUG PRINT ======')
# ----> 3 total_probability = calc_conversion_probability(starting_node, df_transition_prob, 0, calculated_node_probabilities)
#       4 print('====== END DEBUG PRINT ======')
#       5 print(' ')
#
# <ipython-input-25-0fbe4e5fa737> in calc_conversion_probability(starting_state, df_transitions, cum_probability, calculated_nodes, debug)
#      43                                                                 cum_probability + row['probability'],
#      44                                                                 calculated_nodes,
# ---> 45                                                                 debug)
#      46                 node_conversion_prob = child_probability * row['probability']
#      47
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-25-0fbe4e5fa737> in calc_conversion_probability(starting_state, df_transitions, cum_probability, calculated_nodes, debug)
#      43                                                                 cum_probability + row['probability'],
#      44                                                                 calculated_nodes,
# ---> 45                                                                 debug)
#      46                 node_conversion_prob = child_probability * row['probability']
#      47
#
# RuntimeError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# ##### No Final output, error received is "RuntimeError: maximum recursion depth exceeded while calling a Python object"
